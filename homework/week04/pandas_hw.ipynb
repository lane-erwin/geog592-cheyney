# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
filename = "IDN_vulnerability_cleaned.csv"

df = pd.read_csv(filename)

# %%
df.head()
# this is showing the first 5 rows
# this is a method
# Out:
#   ADM2_PCODE  total_pop  total_pop_rural  dependency_ratio  \
# 0     ID1107     213662           112712             45.89
# 1     ID1112     163453            58822             43.29
# 2     ID1108     426779            70767             51.87
# 3     ID1116      94733            61186             53.08
# 4     ID1103     241711            98933             43.34
#
#    dependency_ratio_rural
# 0                   45.89
# 1                   43.30
# 2                   51.92
# 3                   53.08
# 4                   43.35

# %%
df.shape
# this is showing how many rows, columns there are in the dataset
# this is an attribute
# Out:
# (522, 5)

# %%
df.columns

# this will print out the column names
# Out:
# Index(['ADM2_PCODE', 'total_pop', 'total_pop_rural', 'dependency_ratio',
#        'dependency_ratio_rural'],
#       dtype='str')

# %%
df.dtypes

# this will print out the type of columns
# Out:
# ADM2_PCODE                    str
# total_pop                   int64
# total_pop_rural             int64
# dependency_ratio          float64
# dependency_ratio_rural    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ADM2_PCODE              522 non-null    str
#  1   total_pop               522 non-null    int64
#  2   total_pop_rural         522 non-null    int64
#  3   dependency_ratio        522 non-null    float64
#  4   dependency_ratio_rural  522 non-null    float64
# dtypes: float64(2), int64(2), str(1)
# memory usage: 20.5 KB
