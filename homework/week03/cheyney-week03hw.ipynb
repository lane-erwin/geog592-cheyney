# %%
import csv

filename =  "tabela1613.csv"

with open(filename, "r", encoding= "utf-8") as file:
    reader = csv.DictReader(file)
    rows = list(reader)

print(len(rows), "total rows")
for i in range(8):
    print(rows[i])
# Out:
# 5567 total rows
# {'\ufeff"Tabela 1613 - Área destinada à colheita': 'Variável - Rendimento médio da produção', ' área colhida': None, ' quantidade produzida': None, ' rendimento médio e valor da produção das lavouras permanentes"': None}
# {'\ufeff"Tabela 1613 - Área destinada à colheita': 'Nível', ' área colhida': 'Cód.', ' quantidade produzida': 'Município', ' rendimento médio e valor da produção das lavouras permanentes"': 'Ano x Produto das lavouras permanentes'}
# {'\ufeff"Tabela 1613 - Área destinada à colheita': 'Nível', ' área colhida': 'Cód.', ' quantidade produzida': 'Município', ' rendimento médio e valor da produção das lavouras permanentes"': '2024'}
# {'\ufeff"Tabela 1613 - Área destinada à colheita': 'Nível', ' área colhida': 'Cód.', ' quantidade produzida': 'Município', ' rendimento médio e valor da produção das lavouras permanentes"': 'Total', None: ['', 'Açaí', ' ', '']}
# {'\ufeff"Tabela 1613 - Área destinada à colheita': 'MU', ' área colhida': '1100015', ' quantidade produzida': "Alta Floresta D'Oeste (RO)", ' rendimento médio e valor da produção das lavouras permanentes"': '..', None: ['Quilogramas por Hectare', '6000', 'Quilogramas por Hectare']}
# {'\ufeff"Tabela 1613 - Área destinada à colheita': 'MU', ' área colhida': '1100023', ' quantidade produzida': 'Ariquemes (RO)', ' rendimento médio e valor da produção das lavouras permanentes"': '..', None: ['Quilogramas por Hectare', '9167', 'Quilogramas por Hectare']}
# {'\ufeff"Tabela 1613 - Área destinada à colheita': 'MU', ' área colhida': '1100031', ' quantidade produzida': 'Cabixi (RO)', ' rendimento médio e valor da produção das lavouras permanentes"': '..', None: ['Quilogramas por Hectare', '-', 'Quilogramas por Hectare']}
# {'\ufeff"Tabela 1613 - Área destinada à colheita': 'MU', ' área colhida': '1100049', ' quantidade produzida': 'Cacoal (RO)', ' rendimento médio e valor da produção das lavouras permanentes"': '..', None: ['Quilogramas por Hectare', '-', 'Quilogramas por Hectare']}

# %%
for row in rows[:4]:
    print(row)
# Out:
# {'\ufeff"Tabela 1613 - Área destinada à colheita': 'Variável - Rendimento médio da produção', ' área colhida': None, ' quantidade produzida': None, ' rendimento médio e valor da produção das lavouras permanentes"': None}
# {'\ufeff"Tabela 1613 - Área destinada à colheita': 'Nível', ' área colhida': 'Cód.', ' quantidade produzida': 'Município', ' rendimento médio e valor da produção das lavouras permanentes"': 'Ano x Produto das lavouras permanentes'}
# {'\ufeff"Tabela 1613 - Área destinada à colheita': 'Nível', ' área colhida': 'Cód.', ' quantidade produzida': 'Município', ' rendimento médio e valor da produção das lavouras permanentes"': '2024'}
# {'\ufeff"Tabela 1613 - Área destinada à colheita': 'Nível', ' área colhida': 'Cód.', ' quantidade produzida': 'Município', ' rendimento médio e valor da produção das lavouras permanentes"': 'Total', None: ['', 'Açaí', ' ', '']}

# %%
# students code
import csv

filename =  "tabela1613.csv"

with open(filename, "r", encoding= "utf-8") as file:
    reader = csv.reader(file)

    for x in range(4):
        next(reader)

    headers = next(reader)

    reader = csv.DictReader(file, fieldnames=headers)

    rows = list(reader)
cleaned = (rows)
print(cleaned[:5])
# Out:
# [{'Nível': 'MU', 'Cód.': '1100015', 'Município': "Alta Floresta D'Oeste (RO)", 'Total': '..', '': None, 'Açaí': '6000', ' ': 'Quilogramas por Hectare'}, {'Nível': 'MU', 'Cód.': '1100023', 'Município': 'Ariquemes (RO)', 'Total': '..', '': None, 'Açaí': '9167', ' ': 'Quilogramas por Hectare'}, {'Nível': 'MU', 'Cód.': '1100031', 'Município': 'Cabixi (RO)', 'Total': '..', '': None, 'Açaí': '-', ' ': 'Quilogramas por Hectare'}, {'Nível': 'MU', 'Cód.': '1100049', 'Município': 'Cacoal (RO)', 'Total': '..', '': None, 'Açaí': '-', ' ': 'Quilogramas por Hectare'}, {'Nível': 'MU', 'Cód.': '1100056', 'Município': 'Cerejeiras (RO)', 'Total': '..', '': None, 'Açaí': '-', ' ': 'Quilogramas por Hectare'}]

# %%
## look for what doesnt look like a number, then you will get an array
# ask to go through each row of acai and to send into that array whatever is not a number. name it "not_numbers" and then print it out.
# whatever is not a number, append it to the array "not_numbers"
#not_numbers = []
#for row in cleaned:
    #for key, value in row.items():
        #try:
            #float(value)  # Try to convert the value to a float
        #except ValueError:
            #not_numbers.append(value)  # If it fails, append to not_numbers

#print(not_numbers)
#Acai
#nv=[] # create an empty list
nv =[]
for row in rows:
    try:
        float(row['Açaí'])  
    except (ValueError, TypeError):
        nv.append(row['Açaí'])
print(nv)
# Out:
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '...', '-', '-', '-', '-', '...', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '...', '-', '...', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '...', '...', '-', '-', '-', '...', '-', '-', '-', '-', '...', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '...', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '...', '-', '-', '-', '-', '-', '-', '...', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '...', '...', '-', '...', '-', '-', '...', '-', '...', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '...', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '...', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '...', '-', '-', '-', '...', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '...', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '...', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', ...
